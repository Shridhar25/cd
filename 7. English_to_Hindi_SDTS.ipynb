# %%
translations ={
    "What" : "क्या",
    "Where" : "कहां",
    "are" : "हैं",
    "is" : "है",
    "you" : "तुम",
    "he" : "वह",
    "I" : "मैं",
    "going" : "जा रहे",
    "am" : "हूँ", 
}

pronoun=["you","I","he"]
que=["What","Where"]
verb=["is","are","am"]
object=["going"]


def reader():
    sentence=input("Enter the sentence to be translated: ")
    tokens=sentence.split()
    return tokens

def translate(s):
    tr=[]
    ptr=[]
    strr=[]
    vtr=[]
    otr=[]
    for i in s:
        if(i in translations):
            if(i in pronoun):
                ptr.append(translations[i]) 
            elif(i in que):
                strr.append(translations[i])
            elif(i in verb):
                vtr.append(translations[i])
            else:
                otr.append(translations[i])
    for i in ptr:
        tr.append(i)    
    for i in strr:
        tr.append(i)
    for i in otr:
        tr.append(i)
    for i in vtr:
        tr.append(i) 
    return tr
    
# Driver Code
sent = reader()
trd = translate(sent)
print("Translated sentence :-")
for i in trd:
    print(i , end=" ")
# Out:
# Enter the sentence to be translated: Where are you going
# Translated sentence :-
# तुम कहां जा रहे हैं
