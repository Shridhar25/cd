# %%
base_address = 100
curr_address = base_address
statements = []
initialization_value = input("Enter initialisation value")
statements.append(str(curr_address) + " : " + initialization_value)
while_condition = input("Enter while condition")
curr_address+=1
statements.append(str(curr_address) + " : "  + "if " + while_condition + " goto " + str(curr_address +2))
if_stmt_count = int(input("Enter no. of statement inside if"))
else_stmt_count = int(input("Enter no. of statement inside else"))
exit_address = base_address + 3  + 1 + 2*if_stmt_count + 1 + 2*else_stmt_count + 3 +1



curr_address+=1
statements.append(str(curr_address) + " : " + "goto " + str(exit_address))
if_condition = input("Enter the if condition")




if_statements = []
curr_address+=1
statements.append(str(curr_address) + " : "  + "if " +  if_condition + " goto " + str(curr_address +2))
curr_address+=1
statements.append(str(curr_address) + " : " + "goto " + str(curr_address + 2*if_stmt_count + 1 + 1))
var_count = 0
print("Enter satements inside if")
for i in range(if_stmt_count):
    var_count+=1
    k = input().split("=")
    curr_address+=1
    statements.append(str(curr_address) + " : " +"T"+ str(var_count) + " = " + k[1])
    curr_address+=1
    statements.append(str(curr_address) + " : " +k[0] + " = " + "T"+ str(var_count))



else_statements = []
curr_address+=1
statements.append(str(curr_address) + " : " + "goto " + str(curr_address+ 2*else_stmt_count + 1))
print("Enter satements inside else")
for i in range(else_stmt_count):
    var_count+=1
    k = input().split("=")
    curr_address+=1
    statements.append(str(curr_address) + " : " +"T"+ str(var_count) + " = " + k[1])
    curr_address+=1
    statements.append(str(curr_address) + " : " +k[0] + " = " + "T"+ str(var_count))

curr_address+=1
var_count+=1
statements.append(str(curr_address) + " : " +"T"+ str(var_count) + " = " + "i+1")
curr_address+=1
statements.append(str(curr_address) + " : " +"i" + " = " + "T"+ str(var_count))
curr_address+=1
statements.append(str(curr_address) + " : " + "goto " + str(base_address+1))
statements.append(str(exit_address) + " : " + "exit")
for statement in statements:
    print(statement)
# Out:
# Enter initialisation valuei=0
# Enter while conditioni<10
# Enter no. of statement inside if2
# Enter no. of statement inside else2
# Enter the if conditioni<5
# Enter satements inside if
# a=b+c
# b=a+c
# Enter satements inside else
# c=a+b
# b=a+c
# 100 : i=0
# 101 : if i<10 goto 103
# 102 : goto 117
# 103 : if i<5 goto 105
# 104 : goto 110
# 105 : T1 = b+c
# 106 : a = T1
# 107 : T2 = a+c
# 108 : b = T2
# 109 : goto 114
# 110 : T3 = a+b
# 111 : c = T3
# 112 : T4 = a+c
# 113 : b = T4
# 114 : T5 = i+1
# 115 : i = T5
# 116 : goto 101
# 117 : exit
